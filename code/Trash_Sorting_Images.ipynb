# %%
# %cd /content
# Out:
# /content

# %%
# !ls
# Out:
# gggg  sample_data

# %% [markdown]
# # **Computer Vision**

# %% [markdown]
# Import necessary libraries

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# %cd /content/drive/MyDrive/ML2_Project/trashnet/data
# Out:
# /content/drive/MyDrive/ML2_Project/trashnet/data

# %%
import zipfile

zip_path = '/content/drive/MyDrive/ML2_Project/trashnet/data/dataset-resized.zip'
destination_folder = '/content/drive/MyDrive/ML2_Project/trashnet/data'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(destination_folder)

# %%
# !python resize.py

# %% [markdown]
# Define image data generator for training and validation data

# %%
# Define image data generator for training and validation data
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load your dataset
train_set = train_datagen.flow_from_directory('/content/drive/MyDrive/ML2_Project/trashnet/data/dataset-resized',
                                              target_size=(64, 64),
                                              batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 2527 images belonging to 6 classes.

# %% [markdown]
# Build Model

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=6, activation='softmax'))  # 3 units for 3 classes: recyclable, compostable, or trash

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Train Model

# %%
model.fit(train_set, epochs=25)
# Out:
# Epoch 1/25
# 79/79 [==============================] - 31s 368ms/step - loss: 2.1723 - accuracy: 0.3265
# Epoch 2/25
# 79/79 [==============================] - 28s 352ms/step - loss: 1.3716 - accuracy: 0.4610
# Epoch 3/25
# 79/79 [==============================] - 27s 343ms/step - loss: 1.2659 - accuracy: 0.5022
# Epoch 4/25
# 79/79 [==============================] - 29s 369ms/step - loss: 1.2256 - accuracy: 0.5208
# Epoch 5/25
# 79/79 [==============================] - 28s 351ms/step - loss: 1.1746 - accuracy: 0.5509
# Epoch 6/25
# 79/79 [==============================] - 27s 336ms/step - loss: 1.1431 - accuracy: 0.5687
# Epoch 7/25
# 79/79 [==============================] - 27s 340ms/step - loss: 1.1012 - accuracy: 0.5865
# Epoch 8/25
# 79/79 [==============================] - 25s 311ms/step - loss: 1.0686 - accuracy: 0.5956
# Epoch 9/25
# 79/79 [==============================] - 28s 357ms/step - loss: 1.0515 - accuracy: 0.6185
# Epoch 10/25
# ...

# %% [markdown]
# Save and Download Model

# %%
# Save model
model.save('/content/drive/MyDrive/ML2_Project/model/trash_classifier.h5')

from google.colab import files
# Download the model file
files.download('/content/drive/MyDrive/ML2_Project/model/trash_classifier.h5')

# %%
from PIL import Image
import numpy as np

# Load and preprocess the test image
test_image_path = '/content/drive/MyDrive/ML2_Project/test_images/plastic.jpg'
test_image = Image.open(test_image_path)
target_size = (64, 64)
test_image = test_image.resize(target_size)
test_image = np.array(test_image) / 255.0
test_image = np.expand_dims(test_image, axis=0)

# Make predictions on the test image
predictions = model.predict(test_image)

# Get the predicted class index
predicted_class_index = np.argmax(predictions[0])

# Map the predicted class index to the corresponding class label
class_labels = train_set.class_indices
predicted_class_label = {v: k for k, v in class_labels.items()}[predicted_class_index]

# Print the predicted class label
print('Predicted class:', predicted_class_label)
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted class: paper
